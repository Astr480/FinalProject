# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
binary_e = np.linspace(0,1,100)
mu = 0.5
critical_axis = (0.464+0.006)+(-0.380+0.010)*mu + (-0.631+0.034)*binary_e + (0.0586+0.061)*mu*binary_e+(0.150+0.041)*binary_e**2 + (-0.198+0.047)*mu*binary_e**2

critical_axis_l = (0.464-0.006)+(-0.380-0.010)*mu + (-0.631-0.034)*binary_e + (0.0586-0.061)*mu*binary_e+(0.150-0.041)*binary_e**2 + (-0.198-0.047)*mu*binary_e**2

# %%
plt.figure(figsize=(10,10))
plt.plot(binary_e,critical_axis,'bo',markersize = 1,label = 'upper boundry')
plt.plot(binary_e,critical_axis_l,'ro',markersize = 1,label = 'lower boundry')
plt.ylim(0,0.4)
plt.xlabel('Binary e',size = 15)
plt.ylabel('Critical semi major axis(a_b)',size = 15)
plt.legend(fontsize = 15)
plt.text(0.8,0.3,'mu = 0.5')
plt.title('S-type planet critical semi-major axis',size = 15)
plt.savefig('plot1.jpg')

# %%
critical_P = (1.60+0.04)+(5.10+0.05)*binary_e+(4.12+0.09)*mu +(-2.22+0.11)*binary_e**2 + (-4.27+0.17)*mu*binary_e+(-5.09+0.11)*mu**2 + (4.61+0.36)*mu*2*binary_e**2
critical_P_l = (1.60-0.04)+(5.10-0.05)*binary_e+(4.12-0.09)*mu +(-2.22-0.11)*binary_e**2 + (-4.27-0.17)*mu*binary_e+(-5.09-0.11)*mu**2 + (4.61-0.36)*mu*2*binary_e**2

# %%
plt.figure(figsize=(10,10))
plt.plot(binary_e,critical_P,'bo',markersize = 1,label = 'upper boundry')
plt.plot(binary_e,critical_P_l,'ro',markersize = 1,label = 'lower boundry')
plt.ylim(1.5,6)
plt.xlabel('Binary e',size = 15)
plt.ylabel('Critical semi major axis(a_b)',size = 15)
plt.legend(fontsize = 15)
plt.text(0.8,3,'mu = 0.5')
plt.title('P-type planet critical semi-major axis')
plt.savefig('plot2.jpg')

# %%
data = pd.read_csv('binary-star-planet.csv',sep = ';')
mask_planet = data['Star/Planet'] == 0
data[mask_planet]
# Out:
#                                  System  \
# 0            HAT-P-4 b / TYC 2569-744-1
# 2                        HD 38529 Abc B
# 5              HD 20782 b / HD 20781 bc
# 9                        HIP 70849 Ab B
# 11                     HD 125612 Ab-d B
# 15                         HD 222582 AB
# 17                          XO-2 Sbc Nb
# 21                       HD 147513 Ab B
# 23                       HD 213240 Ab C
# 25             HD 190360 (Gl 777 Abc B)
# 28                        WASP-94 Ab Bb
# 31                       HD 89744 Abc B
# 34                       HD 101930 Aa B
# 36              HAT-P-1b (ADS16402 BbA)
# 38                            Kepler-68
# 42                 HD 80606b / HD 80607
# 44                        55 Cnc Ab-f B
# 50         HD 11964 Abc B   (GJ 81.1 A)
# 53                         WASP-70 Ab B
# 55              K2-29 Ab B / WASP-152 b
# 57                       GJ 676 Abcde B
# 62                       HD 142022 Ab B
# ...

# %%
mu = 0.207

critical_axis = (0.464+0.006)+(-0.380+0.010)*mu + (-0.631+0.034)*binary_e + (0.0586+0.061)*mu*binary_e+(0.150+0.041)*binary_e**2 + (-0.198+0.047)*mu*binary_e**2

critical_axis_l = (0.464-0.006)+(-0.380-0.010)*mu + (-0.631-0.034)*binary_e + (0.0586-0.061)*mu*binary_e+(0.150-0.041)*binary_e**2 + (-0.198-0.047)*mu*binary_e**2

plt.figure(figsize=(20,20))
plt.figure(1)
plt.subplot(221)
plt.plot(binary_e,critical_axis,'bo',markersize = 1,label = 'upper boundry')
plt.plot(binary_e,critical_axis_l,'ro',markersize = 1,label = 'lower boundry')
plt.plot(0.26,1.42/100,'go', label = 'HD 19994 b')
plt.ylim(0,0.4)
plt.xlabel('Binary e',size = 15)
plt.ylabel('Critical semi major axis(a_b)',size = 15)
plt.legend(fontsize = 15)
plt.text(0.8,0.3,'mu = 0.207',size = 15)
plt.title('HD 19994 Ab B',size = 15)

mu = 0.283

critical_axis = (0.464+0.006)+(-0.380+0.010)*mu + (-0.631+0.034)*binary_e + (0.0586+0.061)*mu*binary_e+(0.150+0.041)*binary_e**2 + (-0.198+0.047)*mu*binary_e**2

critical_axis_l = (0.464-0.006)+(-0.380-0.010)*mu + (-0.631-0.034)*binary_e + (0.0586-0.061)*mu*binary_e+(0.150-0.041)*binary_e**2 + (-0.198-0.047)*mu*binary_e**2


plt.subplot(222)
plt.plot(binary_e,critical_axis,'bo',markersize = 1,label = 'upper boundry')
plt.plot(binary_e,critical_axis_l,'ro',markersize = 1,label = 'lower boundry')
plt.plot(0.53,0.072/93,'go', label = 'Gliese 15b')
plt.plot(0.53,5.4/93,'yo',label = 'Gliese 15c')
plt.ylim(0,0.4)
plt.xlabel('Binary e',size = 15)
plt.ylabel('Critical semi major axis(a_b)',size = 15)
plt.legend(fontsize = 15)
plt.text(0.8,0.3,'mu = 0.283',size = 15)
plt.title('Gliese 15 AbcB',size = 15)


mu = 0.492

critical_axis = (0.464+0.006)+(-0.380+0.010)*mu + (-0.631+0.034)*binary_e + (0.0586+0.061)*mu*binary_e+(0.150+0.041)*binary_e**2 + (-0.198+0.047)*mu*binary_e**2

critical_axis_l = (0.464-0.006)+(-0.380-0.010)*mu + (-0.631-0.034)*binary_e + (0.0586-0.061)*mu*binary_e+(0.150-0.041)*binary_e**2 + (-0.198-0.047)*mu*binary_e**2


plt.subplot(223)
plt.plot(binary_e,critical_axis,'bo',markersize = 1,label = 'upper boundry')
plt.plot(binary_e,critical_axis_l,'ro',markersize = 1,label = 'lower boundry')
plt.plot(0.42,4.59/345,'go', label = 'HD 106515 b')
plt.ylim(0,0.4)
plt.xlabel('Binary e',size = 15)
plt.ylabel('Critical semi major axis(a_b)',size = 15)
plt.legend(fontsize = 15)
plt.text(0.8,0.3,'mu = 0.492',size = 15)
plt.title('HD 106515 A b',size = 15)

mu = 0.213

critical_axis = (0.464+0.006)+(-0.380+0.010)*mu + (-0.631+0.034)*binary_e + (0.0586+0.061)*mu*binary_e+(0.150+0.041)*binary_e**2 + (-0.198+0.047)*mu*binary_e**2

critical_axis_l = (0.464-0.006)+(-0.380-0.010)*mu + (-0.631-0.034)*binary_e + (0.0586-0.061)*mu*binary_e+(0.150-0.041)*binary_e**2 + (-0.198-0.047)*mu*binary_e**2


plt.subplot(224)
plt.plot(binary_e,critical_axis,'bo',markersize = 1,label = 'upper boundry')
plt.plot(binary_e,critical_axis_l,'ro',markersize = 1,label = 'lower boundry')
plt.plot(0.36,2.05/20,'go', label = 'g Cephei b')
plt.ylim(0,0.4)
plt.xlabel('Binary e',size = 15)
plt.ylabel('Critical semi major axis(a_b)',size = 15)
plt.legend(fontsize = 15)
plt.text(0.8,0.3,'mu = 0.213',size = 15)
plt.title('g Cep Ab B',size = 15)


plt.savefig('plot3.jpg')

# %%
mu = 0.687/(0.687+0.202)

critical_P = (1.60+0.04)+(5.10+0.05)*binary_e+(4.12+0.09)*mu +(-2.22+0.11)*binary_e**2 + (-4.27+0.17)*mu*binary_e+(-5.09+0.11)*mu**2 + (4.61+0.36)*mu*2*binary_e**2
critical_P_l = (1.60-0.04)+(5.10-0.05)*binary_e+(4.12-0.09)*mu +(-2.22-0.11)*binary_e**2 + (-4.27-0.17)*mu*binary_e+(-5.09-0.11)*mu**2 + (4.61-0.36)*mu*2*binary_e**2



plt.figure(figsize=(20,20))
plt.figure(1)
plt.subplot(221)
plt.plot(binary_e,critical_P,'bo',markersize = 1,label = 'lower boundry')
plt.plot(binary_e,critical_P_l,'ro',markersize = 1,label = 'upper boundry')
plt.plot(0.160,0.720/0.224,'go',label = 'Kepler-16')
plt.ylim(1.5,6)
plt.xlabel('Binary e',size = 15)
plt.ylabel('Critical semi major axis(a_b)',size = 15)
plt.legend(fontsize = 15)
plt.text(0.8,3,'mu = 0.773',size = 15)
plt.title('Kepler-16')


mu = 1.049/(1.022+1.049)

critical_P = (1.60+0.04)+(5.10+0.05)*binary_e+(4.12+0.09)*mu +(-2.22+0.11)*binary_e**2 + (-4.27+0.17)*mu*binary_e+(-5.09+0.11)*mu**2 + (4.61+0.36)*mu*2*binary_e**2
critical_P_l = (1.60-0.04)+(5.10-0.05)*binary_e+(4.12-0.09)*mu +(-2.22-0.11)*binary_e**2 + (-4.27-0.17)*mu*binary_e+(-5.09-0.11)*mu**2 + (4.61-0.36)*mu*2*binary_e**2


plt.subplot(222)
plt.plot(binary_e,critical_P,'bo',markersize = 1,label = 'lower boundry')
plt.plot(binary_e,critical_P_l,'ro',markersize = 1,label = 'upper boundry')
plt.plot(0.521,1.086/0.228,'go',label = 'Kepler-34')
plt.ylim(2,7)
plt.xlabel('Binary e',size = 15)
plt.ylabel('Critical semi major axis(a_b)',size = 15)
plt.legend(fontsize = 15)
plt.text(0.8,3,'mu = {0:.3f}'.format(mu),size = 15)
plt.title('Kepler-34')


mu = 0.808/(0.808+0.885)

critical_P = (1.60+0.04)+(5.10+0.05)*binary_e+(4.12+0.09)*mu +(-2.22+0.11)*binary_e**2 + (-4.27+0.17)*mu*binary_e+(-5.09+0.11)*mu**2 + (4.61+0.36)*mu*2*binary_e**2
critical_P_l = (1.60-0.04)+(5.10-0.05)*binary_e+(4.12-0.09)*mu +(-2.22-0.11)*binary_e**2 + (-4.27-0.17)*mu*binary_e+(-5.09-0.11)*mu**2 + (4.61-0.36)*mu*2*binary_e**2


plt.subplot(223)
plt.plot(binary_e,critical_P,'bo',markersize = 1,label = 'lower boundry')
plt.plot(binary_e,critical_P_l,'ro',markersize = 1,label = 'upper boundry')
plt.plot(0.142,0.605/0.176,'go',label = 'Kepler-35')
plt.ylim(2,7)
plt.xlabel('Binary e',size = 15)
plt.ylabel('Critical semi major axis(a_b)',size = 15)
plt.legend(fontsize = 15)
plt.text(0.8,3,'mu = {0:.3f}'.format(mu),size = 15)
plt.title('Kepler-35')


mu = 0.949/(0.949+0.249)

critical_P = (1.60+0.04)+(5.10+0.05)*binary_e+(4.12+0.09)*mu +(-2.22+0.11)*binary_e**2 + (-4.27+0.17)*mu*binary_e+(-5.09+0.11)*mu**2 + (4.61+0.36)*mu*2*binary_e**2
critical_P_l = (1.60-0.04)+(5.10-0.05)*binary_e+(4.12-0.09)*mu +(-2.22-0.11)*binary_e**2 + (-4.27-0.17)*mu*binary_e+(-5.09-0.11)*mu**2 + (4.61-0.36)*mu*2*binary_e**2


plt.subplot(224)
plt.plot(binary_e,critical_P,'bo',markersize = 1,label = 'lower boundry')
plt.plot(binary_e,critical_P_l,'ro',markersize = 1,label = 'upper boundry')
plt.plot(0.103,0.464/0.147,'go',label = 'Kepler-38')
plt.ylim(2,7)
plt.xlabel('Binary e',size = 15)
plt.ylabel('Critical semi major axis(a_b)',size = 15)
plt.legend(fontsize = 15)
plt.text(0.8,3,'mu = {0:.3f}'.format(mu),size = 15)
plt.title('Kepler-38')



plt.savefig('plot4.jpg')
