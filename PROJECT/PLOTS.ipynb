# %%
import astropy.io.fits as fits
import matplotlib.pyplot as plt
import everest

# %%
stars = {'k2-4':201208431,'k2-6':201384232,'k2-7':201393098}
# Out:
# INFO  [everest.user.DownloadFile()]: Found cached file.
# INFO  [everest.user.load_fits()]: Loading FITS file for 201208431.

# %%
#plt.imshow(e[1].data)
e = fits.open('/Users/zllangford/Downloads/hlsp_everest_k2_llc_201208431-c01_kepler_v2.0_lc.fits')
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
ax1.scatter(e[1].data['TIME'],e[1].data['FRAW'],s=1)
ax1.set_title('K2-4',size=20)
#ax1.set_xlim([1975,2060])
#ax1.set_ylim([136800,138000])
ax1.set_ylabel('Raw Flux',size=20)

ax2.scatter(e[1].data['TIME'],e[1].data['FLUX'],s=1)
#ax2.set_xlim([1975,2060])
#ax2.set_ylim([136800,138000])
ax2.set_ylabel('Everest Flux',size=20)
ax2.set_xlabel('Time (BJD - 2454833)',size=20)
plt.savefig('K24.pdf')

# %%
e = fits.open('/Users/zllangford/Downloads/hlsp_everest_k2_llc_201208431-c01_kepler_v2.0_lc.fits')
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
ax1.scatter(e[1].data['TIME'],e[1].data['FRAW'],s=1)
ax1.set_title('K2-4',size=20)
ax1.set_xlim([1970,2060])
ax1.set_ylim([23600,24000])
ax1.set_ylabel('Raw Flux',size=20)

ax2.scatter(e[1].data['TIME'],e[1].data['FLUX'],s=1)
ax2.set_xlim([1970,2060])
ax2.set_ylim([24500,23600])
ax2.set_ylabel('Everest Flux',size=20)
ax2.set_xlabel('Time (BJD - 2454833)',size=20)
plt.savefig('K24.pdf')
# Out:
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.backends.backend_pdf.fontName()]: Assigning font /b'F1' = '/usr/X11/lib/X11/fonts/TTF/Vera.ttf'
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.backends.backend_pdf.writeFonts()]: Embedding font /usr/X11/lib/X11/fonts/TTF/Vera.ttf.
# DEBUG [matplotlib.backends.backend_pdf.writeFonts()]: Writing TrueType font.
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# ...

# %%
e = fits.open('/Users/zllangford/Downloads/hlsp_everest_k2_llc_201393098-c01_kepler_v2.0_lc.fits')
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
ax1.scatter(e[1].data['TIME'],e[1].data['FRAW'],s=1)
ax1.set_title('K2-7',size=20)
ax1.set_xlim([1970,2060])
ax1.set_ylim([23600,24000])
ax1.set_ylabel('Raw Flux',size=20)

ax2.scatter(e[1].data['TIME'],e[1].data['FLUX'],s=1)
ax2.set_xlim([1970,2060])
ax2.set_ylim([24500,23600])
ax2.set_ylabel('Everest Flux',size=20)
ax2.set_xlabel('Time (BJD - 2454833)',size=20)
plt.savefig('K27.pdf')

# %%
star = everest.Everest(201393098)
# Out:
# INFO  [everest.user.DownloadFile()]: Found cached file.
# INFO  [everest.user.load_fits()]: Loading FITS file for 201393098.

# %%
star.plot()
# Out:
# INFO  [everest.user.plot()]: Plotting the light curve...
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# /Users/zllangford/anaconda2/envs/py3/lib/python3.6/site-packages/everest/user.py:791: RuntimeWarning: invalid value encountered in less
#   for i in np.where(flux < ylim[0])[0]:
# /Users/zllangford/anaconda2/envs/py3/lib/python3.6/site-packages/everest/user.py:807: RuntimeWarning: invalid value encountered in greater
#   for i in np.where(flux > ylim[1])[0]:
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# ...

# %%
star = everest.Everest(stars['k2-4'])
#e = fits.open('/Users/zllangford/Downloads/hlsp_everest_k2_llc_201208431-c01_kepler_v2.0_lc.fits')
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
ax1.scatter(star.time,star.fraw,s=1)
ax1.set_title('K2-4',size=20)
#ax1.set_xlim([1975,2060])
ax1.set_ylim([23600,24250])
ax1.set_ylabel('Raw Flux',size=20)

ax2.scatter(star.time,star.fcor,s=1)
#ax2.set_xlim([1975,2060])
ax2.set_ylim([23600,24250])
ax2.set_ylabel('Everest Flux',size=20)
ax2.set_xlabel('Time (BJD - 2454833)',size=20)
plt.savefig('K24.pdf')
# Out:
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.backends.backend_pdf.fontName()]: Assigning font /b'F1' = '/usr/X11/lib/X11/fonts/TTF/Vera.ttf'
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.backends.backend_pdf.writeFonts()]: Embedding font /usr/X11/lib/X11/fonts/TTF/Vera.ttf.
# DEBUG [matplotlib.backends.backend_pdf.writeFonts()]: Writing TrueType font.
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# ...

# %%
star = everest.Everest(stars['k2-6'])
#e = fits.open('/Users/zllangford/Downloads/hlsp_everest_k2_llc_201208431-c01_kepler_v2.0_lc.fits')
fig, (ax1,ax2) = plt.subplots(2,1,figsize=(10,10))
ax1.scatter(star.time,star.fraw,s=1)
ax1.set_title('K2-6',size=20)
#ax1.set_xlim([1975,2060])
ax1.set_ylim([136600,137700])
ax1.set_ylabel('Raw Flux',size=20)

ax2.scatter(star.time,star.fcor,s=1)
#ax2.set_xlim([1975,2060])
ax2.set_ylim([136600,137700])
ax2.set_ylabel('Everest Flux',size=20)
ax2.set_xlabel('Time (BJD - 2454833)',size=20)
plt.savefig('K26.pdf')
# Out:
# INFO  [everest.user.DownloadFile()]: Found cached file.
# INFO  [everest.user.load_fits()]: Loading FITS file for 201384232.
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.backends.backend_pdf.fontName()]: Assigning font /b'F1' = '/usr/X11/lib/X11/fonts/TTF/Vera.ttf'
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.backends.backend_pdf.writeFonts()]: Embedding font /usr/X11/lib/X11/fonts/TTF/Vera.ttf.
# DEBUG [matplotlib.backends.backend_pdf.writeFonts()]: Writing TrueType font.
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# DEBUG [matplotlib.axes._base._update_title_position()]: update_title_pos
# ...
